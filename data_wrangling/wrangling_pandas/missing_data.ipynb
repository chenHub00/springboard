# %%
import numpy as np

# %%
import pandas as pd

# %%
df = pd.DataFrame(np.random.randn(5, 3), index=['a', 'c', 'e', 'f', 'h'],
                      columns=['one', 'two', 'three'])

# %%
df
# Out:
#         one       two     three
# a -1.728668 -0.224033  1.029731
# c -0.523587 -0.458819 -0.730857
# e  0.528344  0.918918  1.002231
# f -0.322356  0.856316 -1.764641
# h  1.191995  0.871700 -0.094862

# %%
df['four'] = 'bar'
df['five'] = df['one'] > 0
df
# Out:
#         one       two     three four   five
# a -1.728668 -0.224033  1.029731  bar  False
# c -0.523587 -0.458819 -0.730857  bar  False
# e  0.528344  0.918918  1.002231  bar   True
# f -0.322356  0.856316 -1.764641  bar  False
# h  1.191995  0.871700 -0.094862  bar   True

# %%
df2 = df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
df2
# Out:
#         one       two     three four   five
# a -1.728668 -0.224033  1.029731  bar  False
# b       NaN       NaN       NaN  NaN    NaN
# c -0.523587 -0.458819 -0.730857  bar  False
# d       NaN       NaN       NaN  NaN    NaN
# e  0.528344  0.918918  1.002231  bar   True
# f -0.322356  0.856316 -1.764641  bar  False
# g       NaN       NaN       NaN  NaN    NaN
# h  1.191995  0.871700 -0.094862  bar   True

# %%
# pandas method
pd.isnull(df2['one'])
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f    False
# g     True
# h    False
# Name: one, dtype: bool

# %%
# series
df2['four'].notnull()
# Out:
# a     True
# b    False
# c     True
# d    False
# e     True
# f     True
# g    False
# h     True
# Name: four, dtype: bool

# %%
# dataframe
df2.isnull()
# Out:
#      one    two  three   four   five
# a  False  False  False  False  False
# b   True   True   True   True   True
# c  False  False  False  False  False
# d   True   True   True   True   True
# e  False  False  False  False  False
# f  False  False  False  False  False
# g   True   True   True   True   True
# h  False  False  False  False  False

# %%
None == None
# Out:
# True

# %%
np.nan == np.nan
# Out:
# False

# %%
# therefore, it might be misleading, only shows false
df['one'] == np.nan
# Out:
# a    False
# c    False
# e    False
# f    False
# h    False
# Name: one, dtype: bool

# %%
# Datatimes
df2 = df.copy()
df2['timestamp'] = pd.Timestamp('20120101')
df2
# Out:
#         one       two     three four   five  timestamp
# a -1.728668 -0.224033  1.029731  bar  False 2012-01-01
# c -0.523587 -0.458819 -0.730857  bar  False 2012-01-01
# e  0.528344  0.918918  1.002231  bar   True 2012-01-01
# f -0.322356  0.856316 -1.764641  bar  False 2012-01-01
# h  1.191995  0.871700 -0.094862  bar   True 2012-01-01

# %%
df2.loc[['a','c','h'],['one','timestamp']] = np.nan
df2
# Out:
#         one       two     three four   five  timestamp
# a       NaN -0.224033  1.029731  bar  False        NaT
# c       NaN -0.458819 -0.730857  bar  False        NaT
# e  0.528344  0.918918  1.002231  bar   True 2012-01-01
# f -0.322356  0.856316 -1.764641  bar  False 2012-01-01
# h       NaN  0.871700 -0.094862  bar   True        NaT

# %%
df2.get_dtype_counts()
# Out:
# bool              1
# datetime64[ns]    1
# float64           3
# object            1
# dtype: int64

# %%
# Inserting missing data
# NsN for numbers
s = pd.Series([1,2,3])
s.loc[0] = None
s
# Out:
# 0    NaN
# 1    2.0
# 2    3.0
# dtype: float64

# %%
# for objects the value given
s = pd.Series(["a", "b", "c"])
s.loc[0] = None
s.loc[1] = np.nan
s
# Out:
# 0    None
# 1     NaN
# 2       c
# dtype: object

# %%
# Calculations with missing data
df[['one','two']]
# Out:
#         one       two
# a -1.728668 -0.224033
# c -0.523587 -0.458819
# e  0.528344  0.918918
# f -0.322356  0.856316
# h  1.191995  0.871700

# %%
df[['one','two','three']]
# Out:
#         one       two     three
# a -1.728668 -0.224033  1.029731
# c -0.523587 -0.458819 -0.730857
# e  0.528344  0.918918  1.002231
# f -0.322356  0.856316 -1.764641
# h  1.191995  0.871700 -0.094862

# %%
# propagation
df[['one','two']] + df[['one','two','three']]
# Out:
#         one  three       two
# a -3.457336    NaN -0.448065
# c -1.047175    NaN -0.917637
# e  1.056689    NaN  1.837836
# f -0.644712    NaN  1.712631
# h  2.383990    NaN  1.743400

# %%
df[['one','two','three']]
# Out:
#         one       two     three
# a -1.728668 -0.224033  1.029731
# c -0.523587 -0.458819 -0.730857
# e  0.528344  0.918918  1.002231
# f -0.322356  0.856316 -1.764641
# h  1.191995  0.871700 -0.094862

# %%
df.loc[['a','c','h'],['one']] = np.nan

# %%
df
# Out:
#         one       two     three four   five
# a       NaN -0.224033  1.029731  bar  False
# c       NaN -0.458819 -0.730857  bar  False
# e  0.528344  0.918918  1.002231  bar   True
# f -0.322356  0.856316 -1.764641  bar  False
# h       NaN  0.871700 -0.094862  bar   True

# %%
df['one'].sum()
# Out:
# 0.20598842494478259

# %%
df.mean(1)
# Out:
# a    0.268566
# c   -0.396558
# e    0.862374
# f   -0.307670
# h    0.592279
# dtype: float64

# %%
df.cumsum()
# Out:
#         one       two     three             four   five
# a       NaN -0.224033   1.02973              bar  False
# c       NaN -0.682851  0.298874           barbar      0
# e  0.528344  0.236067   1.30111        barbarbar      1
# f  0.205988   1.09238 -0.463535     barbarbarbar      1
# h       NaN   1.96408 -0.558397  barbarbarbarbar      2

# %%
# NA values in GroupBy
df.groupby('one').mean()
# Out:
#                 two     three   five
# one
# -0.322356  0.856316 -1.764641  False
#  0.528344  0.918918  1.002231   True

# %%
# Cleaning/filling missing data
## filling missing values: fillna
df2
# Out:
#         one       two     three four   five  timestamp
# a       NaN -0.224033  1.029731  bar  False        NaT
# c       NaN -0.458819 -0.730857  bar  False        NaT
# e  0.528344  0.918918  1.002231  bar   True 2012-01-01
# f -0.322356  0.856316 -1.764641  bar  False 2012-01-01
# h       NaN  0.871700 -0.094862  bar   True        NaT

# %%
df2.fillna(0)
# Out:
#         one       two     three four   five  timestamp
# a  0.000000 -0.224033  1.029731  bar  False 1970-01-01
# c  0.000000 -0.458819 -0.730857  bar  False 1970-01-01
# e  0.528344  0.918918  1.002231  bar   True 2012-01-01
# f -0.322356  0.856316 -1.764641  bar  False 2012-01-01
# h  0.000000  0.871700 -0.094862  bar   True 1970-01-01

# %%
df2['four'].fillna('missing')
# Out:
# a    bar
# c    bar
# e    bar
# f    bar
# h    bar
# Name: four, dtype: object

# %%
### Fill gaps forward or backward
df.fillna(method='pad')
# Out:
#         one       two     three four   five
# a       NaN -0.224033  1.029731  bar  False
# c       NaN -0.458819 -0.730857  bar  False
# e  0.528344  0.918918  1.002231  bar   True
# f -0.322356  0.856316 -1.764641  bar  False
# h -0.322356  0.871700 -0.094862  bar   True

# %%
# limit the amount 
df.loc[['e','f'],['two','three']] = np.nan

# %%
df
# Out:
#         one       two     three four   five
# a       NaN -0.224033  1.029731  bar  False
# c       NaN -0.458819 -0.730857  bar  False
# e  0.528344       NaN       NaN  bar   True
# f -0.322356       NaN       NaN  bar  False
# h       NaN  0.871700 -0.094862  bar   True

# %%
df.fillna(method='pad',limit=1)
# Out:
#         one       two     three four   five
# a       NaN -0.224033  1.029731  bar  False
# c       NaN -0.458819 -0.730857  bar  False
# e  0.528344 -0.458819 -0.730857  bar   True
# f -0.322356       NaN       NaN  bar  False
# h -0.322356  0.871700 -0.094862  bar   True

# %%
# pad/ffill forward fill
# bfill/backfill  backward fill
# alignable
dff = pd.DataFrame(np.random.randn(10,3), columns=list('ABC'))
dff.iloc[3:5,0] = np.nan
dff.iloc[4:6,1] = np.nan
dff.iloc[5:8,2] = np.nan
dff
# Out:
#           A         B         C
# 0  0.237461 -1.482179  0.142737
# 1 -1.916896  0.048031  0.661916
# 2 -0.851745 -1.169174  0.809534
# 3       NaN  0.099137  0.416297
# 4       NaN       NaN  0.477101
# 5  0.294362       NaN       NaN
# 6 -1.412350  1.007052       NaN
# 7  2.451519  0.415144       NaN
# 8 -0.949253 -1.267150 -0.764022
# 9 -0.210458 -1.428479 -0.075075

# %%
dff.fillna(dff.mean())
# Out:
#           A         B         C
# 0  0.237461 -1.482179  0.142737
# 1 -1.916896  0.048031  0.661916
# 2 -0.851745 -1.169174  0.809534
# 3 -0.294670  0.099137  0.416297
# 4 -0.294670 -0.472202  0.477101
# 5  0.294362 -0.472202  0.238355
# 6 -1.412350  1.007052  0.238355
# 7  2.451519  0.415144  0.238355
# 8 -0.949253 -1.267150 -0.764022
# 9 -0.210458 -1.428479 -0.075075

# %%
dff.fillna(dff.mean()['B':'C'])
# Out:
#           A         B         C
# 0  0.237461 -1.482179  0.142737
# 1 -1.916896  0.048031  0.661916
# 2 -0.851745 -1.169174  0.809534
# 3       NaN  0.099137  0.416297
# 4       NaN -0.472202  0.477101
# 5  0.294362 -0.472202  0.238355
# 6 -1.412350  1.007052  0.238355
# 7  2.451519  0.415144  0.238355
# 8 -0.949253 -1.267150 -0.764022
# 9 -0.210458 -1.428479 -0.075075

# %%
dff.where(pd.notnull(dff),dff.mean(),axis='columns')
# Out:
#           A         B         C
# 0  0.237461 -1.482179  0.142737
# 1 -1.916896  0.048031  0.661916
# 2 -0.851745 -1.169174  0.809534
# 3 -0.294670  0.099137  0.416297
# 4 -0.294670 -0.472202  0.477101
# 5  0.294362 -0.472202  0.238355
# 6 -1.412350  1.007052  0.238355
# 7  2.451519  0.415144  0.238355
# 8 -0.949253 -1.267150 -0.764022
# 9 -0.210458 -1.428479 -0.075075

# %%
# Dropping axis labels with missing data
df.loc[['e','f'],['two','three']] = 0
df
# Out:
#         one       two     three four   five
# a       NaN -0.224033  1.029731  bar  False
# c       NaN -0.458819 -0.730857  bar  False
# e  0.528344  0.000000  0.000000  bar   True
# f -0.322356  0.000000  0.000000  bar  False
# h       NaN  0.871700 -0.094862  bar   True

# %%
df.dropna(axis=0)
# Out:
#         one  two  three four   five
# e  0.528344  0.0    0.0  bar   True
# f -0.322356  0.0    0.0  bar  False

# %%
df.dropna(axis=1)
# Out:
#         two     three four   five
# a -0.224033  1.029731  bar  False
# c -0.458819 -0.730857  bar  False
# e  0.000000  0.000000  bar   True
# f  0.000000  0.000000  bar  False
# h  0.871700 -0.094862  bar   True

# %%
df['one'].dropna()
# Out:
# e    0.528344
# f   -0.322356
# Name: one, dtype: float64

# %%
# Interpolation
#ts = pd.DataFrame([['2000-01-31', 0.469112], ['2000-02-29',np.NaN]])
date = ['2000-01-31','2000-02-29','2000-03-31','2000-04-28']
record = [0.469112,np.NaN,np.NaN,np.NaN]

# %%
date
record
# Out:
# [0.469112, nan, nan, nan]

# %%
ts = pd.DataFrame(date,record)
pd.to_datetime(date)
date
# Out:
# ['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-28']
